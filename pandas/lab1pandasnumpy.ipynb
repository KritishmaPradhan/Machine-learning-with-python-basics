# %%
import numpy as  np
import pandas as pd

# %%
data1 = [{'name': 'Kriti', 'age': 20, 'stud_id': 1442},
        {'name': 'Beth', 'age': 25, 'stud_id': 1652},
        {'name': 'Hether', 'age': 19, 'stud_id': 1112},
        {'name': 'Ben', 'age': 22, 'stud_id': 1093}]
data1
# Out:
# [{'name': 'Kriti', 'age': 20, 'stud_id': 1442},
#  {'name': 'Beth', 'age': 25, 'stud_id': 1652},
#  {'name': 'Hether', 'age': 19, 'stud_id': 1112},
#  {'name': 'Ben', 'age': 22, 'stud_id': 1093}]

# %%
listofdict = pd.DataFrame(data1)
listofdict
# Out:
#      name  age  stud_id
# 0   Kriti   20     1442
# 1    Beth   25     1652
# 2  Hether   19     1112
# 3     Ben   22     1093

# %%
data2 = {'name': ['Ben', 'Hem', 'Ted'],
         'age': [20,33,12],
         'nationality': ['Hindu', 'Christian', 'Shikh']}
data2
# Out:
# {'name': ['Ben', 'Hem', 'Ted'],
#  'age': [20, 33, 12],
#  'nationality': ['Hindu', 'Christian', 'Shikh']}

# %%
dictoflist = pd.DataFrame(data2)
dictoflist
# Out:
#   name  age nationality
# 0  Ben   20       Hindu
# 1  Hem   33   Christian
# 2  Ted   12       Shikh

# %%
print(dictoflist.loc[0])                 # selects the first 0 index ROW from data
print(dictoflist.iloc[0,1])              # prints 0 row ko 1 column  cell ko value
# Out:
# name             Ben
# age               20
# nationality    Hindu
# Name: 0, dtype: object
# 20

# %%
print(dictoflist.loc[0, ['age', 'name']])       # gets the 0th row and only age value
# Out:
# age      20
# name    Ben
# Name: 0, dtype: object

# %%
dictoflist.nationality                         # prints only the nationality column
# Out:
# 0        Hindu
# 1    Christian
# 2        Shikh
# Name: nationality, dtype: object

# %%
dictoflist['name']
# Out:
# 0    Ben
# 1    Hem
# Name: name, dtype: object

# %%
# dictoflist.drop(0)                 # drops data for an instance but not in the original dataset 
dictoflist.drop(0, inplace = True)   # drops data from original dataset
dictoflist
# Out:
#   name  age nationality
# 1  Hem   33   Christian
# 2  Ted   12       Shikh

# %%
df1_concat = pd.DataFrame({'A': ['A0', 'A1'], 'B': ['B0', 'B1'], 'key': ['K0', 'K1']})
df2_concat = pd.DataFrame({'A': ['A2', 'A3'], 'B': ['B2', 'B3'], 'key': ['K0', 'K2']})
df3_concat = pd.DataFrame({'C': ['C0', 'C1'], 'D': ['D0', 'D1']}, index=[0,1]) # Matching index for column concat

# %%
# Concatenating along rows (axis=0 is default)
# This stacks df2_concat below df1_concat.
# ignore_index=True creates a new continuous index for the resulting DataFrame.
concatenated_rows = pd.concat([df1_concat, df2_concat], ignore_index = False, axis = 0)       # try axis = 1 for column join
print("Concatenated along rows (ignore_index=True):")
concatenated_rows
# Out:
# Concatenated along rows (ignore_index=True):
#     A   B key
# 0  A0  B0  K0
# 1  A1  B1  K1
# 0  A2  B2  K0
# 1  A3  B3  K2

# %%
# Try it yourself part
df_sales_q1 = pd.DataFrame({'product': ['Mobile', 'Laptop'], 'sales_q1': [100, 150]})
df_sales_q2 = pd.DataFrame({'product': ['Fridge', 'Macbook'], 'sales_q2': [120, 130]})
df_info = pd.DataFrame({'product': ['headphone', 'Oven'], 'manufacturer': ['ManuX', 'ManuY']})
df_sales_q1
# Out:
#   product  sales_q1
# 0  Mobile       100
# 1  Laptop       150

# %%
# --- Reading CSV --- 
try:
    df_from_csv = pd.read_csv('data/sample.csv')
    print("DataFrame from CSV ('data/sample.csv'):")
    print(df_from_csv)
except FileNotFoundError:
    print("sample.csv not found. Please ensure the file exists in the correct location.")
print("\n" + "-"*50 + "\n")
# Out:
# DataFrame from CSV ('data/sample.csv'):
#               Name  Grade  Favorite Subject
# 0      Alice Smith     10       Mathematics
# 1      Bob Johnson      9           History
# 2    Charlie Brown     11           Science
# 3        Diana Lee     12           English
# 4      Ethan Davis     10  Computer Science
# 5     Fiona Garcia      9               Art
# 6    George Wilson     11           Physics
# 7  Hannah Martinez     12             Music
#
# --------------------------------------------------

# %%
# --- Reading TSV (Tab Separated Values) ---
# For TSV files, you specify the delimiter as '\t'.
try:
    df_from_tsv = pd.read_csv('data/sample.tsv', sep='\t')
    print("DataFrame from TSV ('data/sample.tsv'):")
    print(df_from_tsv)
except FileNotFoundError:
    print("sample.tsv not found. Please ensure the file exists in the correct location.")
print("\n" + "-"*50 + "\n")
# Out:
# DataFrame from TSV ('data/sample.tsv'):
#               Name  Grade  Favorite Subject
# 0      Alice Smith     10       Mathematics
# 1      Bob Johnson      9           History
# 2    Charlie Brown     11           Science
# 3        Diana Lee     12           English
# 4      Ethan Davis     10  Computer Science
# 5     Fiona Garcia      9               Art
# 6    George Wilson     11           Physics
# 7  Hannah Martinez     12             Music
#
# --------------------------------------------------

# %%
# --- Reading Excel ---
try:
    # You can specify the sheet name or sheet index (0-based).
    df_from_excel = pd.read_excel('data/sample.xlsx', engine='openpyxl')
    print("DataFrame from Excel ('data/sample.xlsx'):")
    print(df_from_excel)
    
    # Example: Reading another sheet if it existed
    # df_excel_sheet2 = pd.read_excel('sample.xlsx', sheet_name='SheetBeta') 
except FileNotFoundError:
    print("sample.xlsx not found. Please ensure the file exists or was created successfully.")
except ImportError:
    print("'openpyxl' library is not installed. Use pip or conda to install openpyxl.")
except Exception as e:
    # Catching other potential errors like sheet not found
    print(f"Error reading Excel file: {e}")
# Out:
# DataFrame from Excel ('data/sample.xlsx'):
#               Name  Grade  Favorite Subject
# 0      Alice Smith     10       Mathematics
# 1      Bob Johnson      9           History
# 2    Charlie Brown     11           Science
# 3        Diana Lee     12           English
# 4      Ethan Davis     10  Computer Science
# 5     Fiona Garcia      9               Art
# 6    George Wilson     11           Physics
# 7  Hannah Martinez     12             Music

# %%
data_clean_raw = {
    'id': [1, 2, 3, 4, 5, 2, 6, 7], # Note: duplicate id '2'
    'item_name': ['Apple', 'Banana', 'Orange', np.nan, 'Grape', 'Banana', 'Melon', 'Apple'],
    'quantity': [10, 15, np.nan, 20, 25, 15, 30, 10],
    'price_str': ['5.0', '3.0', '4.5', '7.0', '6.2', '3.0', '10.0', '5.0'],
    'category': ['Fruit', 'Fruit', 'Fruit', 'Vegetable', 'Fruit', 'Fruit', 'Fruit', 'Fruit']
}

# %%
uncleandata_new = pd.DataFrame(data_clean_raw)
uncleandata_new
# Out:
#    id item_name  quantity price_str   category
# 0   1     Apple      10.0       5.0      Fruit
# 1   2    Banana      15.0       3.0      Fruit
# 2   3    Orange       NaN       4.5      Fruit
# 3   4       NaN      20.0       7.0  Vegetable
# 4   5     Grape      25.0       6.2      Fruit
# 5   2    Banana      15.0       3.0      Fruit
# 6   6     Melon      30.0      10.0      Fruit
# 7   7     Apple      10.0       5.0      Fruit

# %%
uncleandata_new.set_index("id", inplace = True)
uncleandata_new
# Out:
#    item_name  quantity price_str   category
# id
# 1      Apple      10.0       5.0      Fruit
# 2     Banana      15.0       3.0      Fruit
# 3     Orange       NaN       4.5      Fruit
# 4        NaN      20.0       7.0  Vegetable
# 5      Grape      25.0       6.2      Fruit
# 2     Banana      15.0       3.0      Fruit
# 6      Melon      30.0      10.0      Fruit
# 7      Apple      10.0       5.0      Fruit

# %%
try:
    housingdata_csv = pd.read_csv('data/housing.csv')
    print("DataFrame from CSV ('data/housing.csv'):")
    print(housingdata_csv)
except FileNotFoundError:
    print("sample.csv not found. Please ensure the file exists in the correct location.")
print("\n" + "-"*50 + "\n")
# Out:
# DataFrame from CSV ('data/housing.csv'):
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housingdatadf = pd.DataFrame(housingdata_csv)
housingdatadf
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housingdatadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housingdatadf.describe()           # describes the statistical attributes
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing3000 = housingdatadf['median_house_value']<= 30000        # boolean masking 
housing3000.value_counts()                                       # returns number of true/false if data <= 30000
# Out:
# median_house_value
# False    20624
# True        16
# Name: count, dtype: int64

# %%
housingdatadf[housing3000]        # extract only data that have medianhouse value <= 30000
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1825     -122.32     37.93                33.0        296.0            73.0
# 2521     -122.74     39.71                16.0        255.0            73.0
# 2778     -115.73     33.35                23.0       1586.0           448.0
# 2779     -114.65     32.79                21.0         44.0            33.0
# 2799     -117.02     36.40                19.0        619.0           239.0
# 3018     -119.45     35.07                45.0        973.0           183.0
# 3027     -119.45     35.13                34.0       1440.0           309.0
# 3028     -119.46     35.13                46.0       2745.0           543.0
# 5887     -118.33     34.15                39.0        493.0           168.0
# 9188     -117.86     34.24                52.0        803.0           267.0
# 12444    -114.67     33.92                17.0         97.0            24.0
# ...

# %%
data_orders = {
    'Order_ID': [1001, 1002, 1003, 1004, 1005],
    'Customer_Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Ethan'],
    'Drink': ['Latte', 'Espresso', 'Cappuccino', 'Flat White', 'Americano'],
    'Size': ['Medium', 'Small', 'Large', 'Medium', 'Large'],
    'Price': [3.50, 2.00, 4.00, 3.75, 3.25],
    'Tip': [0.50, 0.00, 1.00, 0.25, 0.75],
    'Payment_Method': ['Card', 'Cash', 'Card', 'Card', 'Mobile'],
    'Order_Time': ['08:15', '09:00', '08:45', '10:30', '11:00']
}
df_apply_map = pd.DataFrame(data_orders)

# %%
df_apply_map['Size'].value_counts()     # counts number of medium small large
# Out:
# Size
# Medium    2
# Large     2
# Small     1
# Name: count, dtype: int64

# %%
df_apply_map['Size'] = df_apply_map['Size'].map(lambda x:x.lower())     # work in series,changes uppercase to lowercase

# %%
df_apply_map
# Out:
#    Order_ID Customer_Name       Drink    Size  Price   Tip Payment_Method  \
# 0      1001         Alice       Latte  medium   3.50  0.50           Card
# 1      1002           Bob    Espresso   small   2.00  0.00           Cash
# 2      1003       Charlie  Cappuccino   large   4.00  1.00           Card
# 3      1004         Diana  Flat White  medium   3.75  0.25           Card
# 4      1005         Ethan   Americano   large   3.25  0.75         Mobile
#
#   Order_Time
# 0      08:15
# 1      09:00
# 2      08:45
# 3      10:30
# 4      11:00

# %%
df_applymap_dict = {'small': 3, 'medium': 2, 'large': 4}            # changes small medium and so value to 3,2,4
df_apply_map['Size'] = df_apply_map['Size'].map(df_applymap_dict)    # maps value
df_apply_map
# Out:
#    Order_ID Customer_Name       Drink  Size  Price   Tip Payment_Method  \
# 0      1001         Alice       Latte     2   3.50  0.50           Card
# 1      1002           Bob    Espresso     3   2.00  0.00           Cash
# 2      1003       Charlie  Cappuccino     4   4.00  1.00           Card
# 3      1004         Diana  Flat White     2   3.75  0.25           Card
# 4      1005         Ethan   Americano     4   3.25  0.75         Mobile
#
#   Order_Time
# 0      08:15
# 1      09:00
# 2      08:45
# 3      10:30
# 4      11:00

# %%
data_groupby = {
    'Department': [
        'HR', 'Tech', 'HR', 'Tech', 'Marketing', 'Tech', 'Marketing',
        'Sales', 'HR', 'Tech', 'Sales', 'Marketing', 'HR', 'Tech', 'Sales'
    ],
    'Employee': [
        'Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace',
        'Hannah', 'Ian', 'Jack', 'Karen', 'Laura', 'Mike', 'Nina', 'Oscar'
    ],
    'Salary': [
        70000, 80000, 65000, 95000, 75000, 82000, 72000,
        68000, 62000, 87000, 66000, 73000, 64000, 90000, 69000
    ],
    'Projects': [
        3, 5, 2, 6, 4, 4, 3,
        2, 1, 5, 3, 4, 2, 5, 2
    ]
}

df_groupby_ops = pd.DataFrame(data_groupby)
print("Original DataFrame for groupby operations:")
df_groupby_ops
# Out:
# Original DataFrame for groupby operations:
#    Department Employee  Salary  Projects
# 0          HR    Alice   70000         3
# 1        Tech      Bob   80000         5
# 2          HR  Charlie   65000         2
# 3        Tech    David   95000         6
# 4   Marketing      Eve   75000         4
# 5        Tech    Frank   82000         4
# 6   Marketing    Grace   72000         3
# 7       Sales   Hannah   68000         2
# 8          HR      Ian   62000         1
# 9        Tech     Jack   87000         5
# 10      Sales    Karen   66000         3
# 11  Marketing    Laura   73000         4
# 12         HR     Mike   64000         2
# 13       Tech     Nina   90000         5
# 14      Sales    Oscar   69000         2

# %%
df_groupby_dept = df_groupby_ops.groupby('Department')['Salary'].mean()    # eg:in dept, makes Tech group finds mean of salary 
df_groupby_dept
# Out:
# Department
# HR           65250.000000
# Marketing    73333.333333
# Sales        67666.666667
# Tech         86800.000000
# Name: Salary, dtype: float64

# %%
df_groupby_emp = df_groupby_ops.groupby('Department')['Employee'].agg(list)     # aggregates
df_groupby_emp
# Out:
# Department
# HR               [Alice, Charlie, Ian, Mike]
# Marketing                [Eve, Grace, Laura]
# Sales                 [Hannah, Karen, Oscar]
# Tech         [Bob, David, Frank, Jack, Nina]
# Name: Employee, dtype: object

# %%
employeedata_csv = pd.read_csv('data/employee_datasetMLpandas.csv')
DFemployee = pd.DataFrame(employeedata_csv)
DFemployee
# Out:
#    Empid    Employeeename Department     Salary  Age Designation
# 0   E001    Laura Johnson    Finance   53220.17   38    Director
# 1   E002  Chris Rodriguez    Finance   72196.74   24   Executive
# 2   E003   Katie Martinez        NaN   43300.98   57         NaN
# 3   E004      Emily Smith      Sales   72241.28  NaN     Manager
# 4   E005   David Martinez         IT  115553.77   23    Director
# ..   ...              ...        ...        ...  ...         ...
# 95  E096      Chris Davis         HR   55394.43   53      Intern
# 96  E097   John Rodriguez         IT   91064.32   23   Assistant
# 97  E098   Katie Williams    Finance   32950.48   52   Executive
# 98  E099    Michael Brown        NaN   69608.31   41     Analyst
# 99  E100  David Rodriguez         IT   52810.59   47   Undefined
#
# [100 rows x 6 columns]

# %%
DFemployee.head()                           # first five rows
# Out:
#   Empid    Employeeename Department     Salary  Age Designation
# 0  E001    Laura Johnson    Finance   53220.17   38    Director
# 1  E002  Chris Rodriguez    Finance   72196.74   24   Executive
# 2  E003   Katie Martinez        NaN   43300.98   57         NaN
# 3  E004      Emily Smith      Sales   72241.28  NaN     Manager
# 4  E005   David Martinez         IT  115553.77   23    Director

# %%
DFemployee.isnull()                 # null is represented by True else false
# Out:
#     Empid  Employeeename  Department  Salary    Age  Designation
# 0   False          False       False   False  False        False
# 1   False          False       False   False  False        False
# 2   False          False        True   False  False         True
# 3   False          False       False   False   True        False
# 4   False          False       False   False  False        False
# ..    ...            ...         ...     ...    ...          ...
# 95  False          False       False   False  False        False
# 96  False          False       False   False  False        False
# 97  False          False       False   False  False        False
# 98  False          False        True   False  False        False
# 99  False          False       False   False  False        False
#
# [100 rows x 6 columns]

# %%
DFemployee.isnull().sum()             # number of null value shown in each column
# Out:
# Empid             0
# Employeeename     0
# Department       13
# Salary           13
# Age               9
# Designation       9
# dtype: int64

# %%
DFemployee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Empid          100 non-null    object
#  1   Employeeename  100 non-null    object
#  2   Department     87 non-null     object
#  3   Salary         87 non-null     float64
#  4   Age            91 non-null     object
#  5   Designation    91 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 4.8+ KB

# %%
DFemployee.fillna(0)              # replace null values with 0
# Out:
#    Empid    Employeeename Department     Salary Age Designation
# 0   E001    Laura Johnson    Finance   53220.17  38    Director
# 1   E002  Chris Rodriguez    Finance   72196.74  24   Executive
# 2   E003   Katie Martinez          0   43300.98  57           0
# 3   E004      Emily Smith      Sales   72241.28   0     Manager
# 4   E005   David Martinez         IT  115553.77  23    Director
# ..   ...              ...        ...        ...  ..         ...
# 95  E096      Chris Davis         HR   55394.43  53      Intern
# 96  E097   John Rodriguez         IT   91064.32  23   Assistant
# 97  E098   Katie Williams    Finance   32950.48  52   Executive
# 98  E099    Michael Brown          0   69608.31  41     Analyst
# 99  E100  David Rodriguez         IT   52810.59  47   Undefined
#
# [100 rows x 6 columns]
